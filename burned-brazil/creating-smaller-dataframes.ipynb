# %% [markdown]
# # creating smaller dataframes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import time

# %%
df2014 = pd.read_csv('../../dataset/data2014.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2015 = pd.read_csv('../../dataset/data2015.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2016 = pd.read_csv('../../dataset/data2016.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2017 = pd.read_csv('../../dataset/data2017.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2018 = pd.read_csv('../../dataset/data2018.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2019 = pd.read_csv('../../dataset/data2019.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)
df2020 = pd.read_csv('../../dataset/data2020.csv', index_col = 'datahora', usecols = ['riscofogo', 'precipitacao', 'bioma', 'datahora', 'latitude', 'longitude', 'satelite'], parse_dates = True)

# %%
dataframes = [df2014, df2015, df2016, df2017, df2018, df2019, df2020]
biomes = ['Amazonia', 'Caatinga', 'Pantanal', 'Mata Atlantica', 'Pampa', 'Cerrado']

# %% [markdown]
# Accordingly to *Validação de focos de queimadas no Cerrado emimagens TM/Landsat-5*
# by S. C. de Jesus, A. W. Setzer and F. Morelli, researchers from INPE have developed
# an algorithm implemented in the data acquisition from satellites *AQUA* and *TERRA*
# in an attempt to minimize the mislabeling of focus fire. Therefore we will use these
# data.

# %%
for dataframe in dataframes:
    dataframe = dataframe[(dataframe.satelite == 'AQUA_M-T') | (dataframe.satelite == 'AQUA_M-M') |
                         (dataframe.satelite == 'TERRA_M-T') | (dataframe.satelite == 'TERRA_M-M')]
    dataframe.drop(columns = ['satelite'])

# %%
for dataframe in dataframes:
    for biome in biomes:
        
        df_yb = dataframe[(dataframe.bioma == biome) & (dataframe.riscofogo == 1)].copy()
        df_yb = df_yb.resample('D')[['riscofogo', 'precipitacao']].sum()
        year = str(dataframe.index[0].year)
        df_yb.to_csv('cleaned-datasets/timeseries{}{}.csv'.format(year, biome))

# %%
df_map = pd.read_csv('../../dataset/data2014.csv', usecols = ['latitude', 'longitude', 'bioma'], parse_dates = True)

# %%
df_map = df_map.round(2)
print (len(df_map))
df_map = df_map.drop_duplicates()
print (len(df_map))
# Out:
# 1855695
# 730029

# %%
df_map.to_csv('cleaned-datasets/data-map.csv')

# %%
for dataframe in dataframes:
    df = dataframe[['riscofogo', 'latitude', 'longitude']].copy().round(2)
    df = df[df.riscofogo == 1]
    year = df.index.year[0]
    df.to_csv('cleaned-datasets/entire_country{}.csv'.format(year))
    print (df.head())
# Out:
#                      riscofogo  latitude  longitude
# datahora
# 2014-10-14 17:21:00        1.0    -20.68     -46.52
# 2014-10-31 17:06:00        1.0     -4.41     -44.51
# 2014-11-12 16:41:00        1.0     -3.70     -44.12
# 2014-10-28 15:45:00        1.0     -3.65     -44.64
# 2014-11-01 16:47:00        1.0     -5.20     -45.56
#                      riscofogo  latitude  longitude
# datahora
# 2015-10-25 05:37:48        1.0     -1.30     -53.52
# 2015-09-18 20:46:27        1.0     -6.44     -44.13
# 2015-12-29 17:30:00        1.0     -5.02     -50.48
# 2015-09-04 14:00:00        1.0    -10.74     -50.66
# 2015-12-29 15:00:00        1.0     -4.30     -46.85
#                      riscofogo  latitude  longitude
# datahora
# 2016-07-25 16:45:00        1.0    -10.51     -50.44
# 2016-10-16 17:54:09        1.0     -5.52     -42.92
# 2016-09-12 05:13:00        1.0    -11.66     -53.61
# 2016-09-12 05:13:00        1.0    -12.79     -53.42
# 2016-12-01 00:51:55        1.0      2.44     -50.81
#                      riscofogo  latitude  longitude
# datahora
# 2017-01-02 15:29:00        1.0     -4.58     -39.45
# 2017-01-01 15:48:00        1.0     -4.16     -40.49
# 2017-01-01 04:50:00        1.0     -4.00     -38.23
# 2017-01-04 16:32:00        1.0     -4.27     -39.59
# 2017-01-05 16:13:00        1.0     -4.78     -41.18
#                      riscofogo  latitude  longitude
# datahora
# 2018-01-02 21:04:48        1.0     -6.33     -39.59
# 2018-01-02 16:24:00        1.0     -6.37     -39.22
# 2018-01-02 19:34:51        1.0     -5.91     -39.78
# 2018-01-02 15:01:05        1.0    -10.96     -39.35
# 2018-01-02 18:44:28        1.0     -7.00     -39.84
#                      riscofogo  latitude  longitude
# datahora
# 2019-01-01 16:00:00        1.0     -7.65     -36.95
# 2019-01-01 16:38:24        1.0     -5.56     -39.58
# 2019-01-01 16:38:24        1.0     -5.33     -39.52
# 2019-01-01 16:38:24        1.0     -4.63     -40.33
# 2019-01-01 21:49:42        1.0     -7.38     -35.16
#                      riscofogo  latitude  longitude
# datahora
# 2020-02-19 16:04:41        1.0     -7.38     -36.06
# 2020-02-19 16:04:41        1.0     -7.40     -36.00
# 2020-02-19 16:04:41        1.0     -7.38     -36.00
# 2020-02-20 16:35:55        1.0      3.89     -60.23
# 2020-02-20 16:35:55        1.0      3.87     -60.23

# %%
for dataframe in dataframes:
    for biome in biomes:
        df = dataframe[['riscofogo', 'latitude', 'longitude', 'bioma']].copy().round(2)
        df = df[df.riscofogo == 1]
        df = df[df.bioma == biome]
        year = df.index.year[0]
        df.to_csv('cleaned-datasets/lat_long{}{}.csv'.format(year,biome))
        print (biome, year)
        print (df.head(3))
        print (' ')
        print (' ')
# Out:
# Amazonia 2014
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2014-08-20 17:42:00        1.0     -8.49     -61.48  Amazonia
# 2014-08-20 17:41:00        1.0    -11.64     -54.55  Amazonia
# 2014-08-01 21:00:00        1.0     -5.08     -48.37  Amazonia
#
#
# Caatinga 2014
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2014-11-03 16:08:00        1.0     -7.76     -41.15  Caatinga
# 2014-11-09 15:54:00        1.0    -14.33     -41.52  Caatinga
# 2014-10-29 16:02:00        1.0     -7.61     -37.97  Caatinga
#
#
# Pantanal 2014
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2014-10-23 20:01:59        1.0    -18.70     -56.93  Pantanal
# 2014-10-13 17:39:00        1.0    -22.09     -57.76  Pantanal
# 2014-08-20 17:39:00        1.0    -19.38     -56.56  Pantanal
#
#
# Mata Atlantica 2014
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2014-07-17 16:46:00        1.0    -26.05     -49.90  Mata Atlantica
# 2014-10-12 03:49:00        1.0    -22.81     -52.78  Mata Atlantica
# 2014-10-22 16:32:00        1.0    -14.42     -39.90  Mata Atlantica
#
#
# Pampa 2014
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2014-08-20 17:49:00        1.0    -29.40     -55.73  Pampa
# 2014-08-20 17:49:00        1.0    -28.86     -55.68  Pampa
# 2014-08-20 17:49:00        1.0    -29.45     -55.62  Pampa
#
#
# Cerrado 2014
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2014-10-14 17:21:00        1.0    -20.68     -46.52  Cerrado
# 2014-10-31 17:06:00        1.0     -4.41     -44.51  Cerrado
# 2014-11-12 16:41:00        1.0     -3.70     -44.12  Cerrado
#
#
# Amazonia 2015
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2015-10-25 05:37:48        1.0     -1.30     -53.52  Amazonia
# 2015-12-29 17:30:00        1.0     -5.02     -50.48  Amazonia
# 2015-12-29 15:00:00        1.0     -4.30     -46.85  Amazonia
#
#
# Caatinga 2015
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2015-01-20 03:41:00        1.0    -10.07     -36.38  Caatinga
# 2015-11-07 01:11:00        1.0     -6.91     -39.87  Caatinga
# 2015-10-26 03:46:00        1.0     -8.45     -43.12  Caatinga
#
#
# Pantanal 2015
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2015-06-18 02:34:00        1.0    -19.08     -55.68  Pantanal
# 2015-06-26 17:36:00        1.0    -19.75     -57.83  Pantanal
# 2015-06-26 17:36:00        1.0    -20.16     -57.47  Pantanal
#
#
# Mata Atlantica 2015
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2015-01-20 03:41:00        1.0    -10.04     -36.25  Mata Atlantica
# 2015-10-11 04:32:00        1.0    -19.31     -42.87  Mata Atlantica
# 2015-11-04 13:07:00        1.0    -15.63     -39.01  Mata Atlantica
#
#
# Pampa 2015
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2015-08-03 13:43:00        1.0    -29.32     -55.65  Pampa
# 2015-04-01 13:18:00        1.0    -29.88     -51.83  Pampa
# 2015-08-02 17:18:00        1.0    -29.36     -55.88  Pampa
#
#
# Cerrado 2015
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2015-09-18 20:46:27        1.0     -6.44     -44.13  Cerrado
# 2015-09-04 14:00:00        1.0    -10.74     -50.66  Cerrado
# 2015-10-18 05:16:45        1.0     -5.45     -43.74  Cerrado
#
#
# Amazonia 2016
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2016-09-12 05:13:00        1.0    -11.66     -53.61  Amazonia
# 2016-09-12 05:13:00        1.0    -12.79     -53.42  Amazonia
# 2016-12-01 00:51:55        1.0      2.44     -50.81  Amazonia
#
#
# Caatinga 2016
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2016-10-16 17:54:09        1.0     -5.52     -42.92  Caatinga
# 2016-07-24 03:46:00        1.0     -9.49     -40.26  Caatinga
# 2016-08-03 04:21:00        1.0     -3.01     -41.74  Caatinga
#
#
# Pantanal 2016
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2016-06-17 05:09:00        1.0    -19.52     -57.66  Pantanal
# 2016-06-17 05:09:00        1.0    -19.53     -57.66  Pantanal
# 2016-08-05 22:25:02        1.0    -19.85     -57.95  Pantanal
#
#
# Mata Atlantica 2016
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2016-10-22 04:25:00        1.0    -18.24     -42.18  Mata Atlantica
# 2016-04-07 05:05:00        1.0    -22.84     -52.20  Mata Atlantica
# 2016-08-10 04:32:00        1.0    -20.89     -41.61  Mata Atlantica
#
#
# Pampa 2016
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2016-03-16 04:15:00        1.0    -31.94     -53.71  Pampa
# 2016-08-24 22:03:31        1.0    -28.48     -55.09  Pampa
# 2016-09-30 05:42:00        1.0    -29.51     -55.65  Pampa
#
#
# Cerrado 2016
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2016-07-25 16:45:00        1.0    -10.51     -50.44  Cerrado
# 2016-03-24 04:49:00        1.0    -12.93     -49.78  Cerrado
# 2016-04-14 05:09:00        1.0    -17.20     -53.44  Cerrado
#
#
# Amazonia 2017
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2017-01-13 04:26:00        1.0     -6.94     -48.68  Amazonia
# 2017-05-31 04:39:00        1.0     -8.68     -51.42  Amazonia
# 2017-05-31 04:39:00        1.0     -8.68     -51.42  Amazonia
#
#
# Caatinga 2017
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2017-01-02 15:29:00        1.0     -4.58     -39.45  Caatinga
# 2017-01-01 15:48:00        1.0     -4.16     -40.49  Caatinga
# 2017-01-01 04:50:00        1.0     -4.00     -38.23  Caatinga
#
#
# Pantanal 2017
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2017-01-08 14:04:00        1.0    -19.20     -57.15  Pantanal
# 2017-01-08 04:23:00        1.0    -17.69     -55.11  Pantanal
# 2017-01-08 04:24:00        1.0    -19.22     -57.15  Pantanal
#
#
# Mata Atlantica 2017
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2017-02-17 16:06:00        1.0     -5.41     -35.37  Mata Atlantica
# 2017-02-20 04:17:00        1.0    -21.60     -46.80  Mata Atlantica
# 2017-02-20 16:46:00        1.0    -21.39     -43.51  Mata Atlantica
#
#
# Pampa 2017
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2017-02-09 16:50:00        1.0    -30.10     -50.28  Pampa
# 2017-04-08 04:39:00        1.0    -32.16     -53.48  Pampa
# 2017-06-23 17:48:00        1.0    -29.96     -55.97  Pampa
#
#
# Cerrado 2017
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2017-04-05 01:37:00        1.0    -22.06     -46.90  Cerrado
# 2017-04-05 16:21:00        1.0    -22.29     -46.91  Cerrado
# 2017-05-19 22:15:50        1.0     -9.65     -48.54  Cerrado
#
#
# Amazonia 2018
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2018-01-02 20:20:33        1.0      0.66     -60.12  Amazonia
# 2018-01-07 16:30:00        1.0      3.06     -60.91  Amazonia
# 2018-01-02 19:35:02        1.0     -4.14     -45.56  Amazonia
# Caatinga 2018
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2018-01-02 21:04:48        1.0     -6.33     -39.59  Caatinga
# 2018-01-02 16:24:00        1.0     -6.37     -39.22  Caatinga
# 2018-01-02 19:34:51        1.0     -5.91     -39.78  Caatinga
#
#
# Pantanal 2018
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2018-02-06 17:06:00        1.0    -19.35     -57.59  Pantanal
# 2018-02-07 01:25:29        1.0    -19.03     -55.32  Pantanal
# 2018-02-15 17:36:00        1.0    -22.04     -57.74  Pantanal
#
#
# Mata Atlantica 2018
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2018-01-02 16:18:00        1.0    -12.97     -39.62  Mata Atlantica
# 2018-01-02 12:25:00        1.0     -9.84     -36.09  Mata Atlantica
# 2018-01-02 16:04:08        1.0    -12.61     -39.26  Mata Atlantica
#
#
# Pampa 2018
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2018-01-12 16:30:00        1.0    -30.55     -54.31  Pampa
# 2018-01-12 05:48:00        1.0    -29.88     -54.80  Pampa
# 2018-01-12 16:30:00        1.0    -30.55     -54.30  Pampa
#
#
# Cerrado 2018
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2018-01-03 16:05:00        1.0     -2.87     -42.04  Cerrado
# 2018-01-03 16:05:00        1.0     -2.87     -42.03  Cerrado
# 2018-01-03 16:05:00        1.0     -2.88     -42.04  Cerrado
#
#
# Amazonia 2019
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2019-01-01 05:51:09        1.0      2.67     -60.92  Amazonia
# 2019-01-01 16:42:40        1.0      2.96     -60.70  Amazonia
# 2019-01-03 21:05:55        1.0      3.94     -61.24  Amazonia
#
#
# Caatinga 2019
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2019-01-01 16:00:00        1.0     -7.65     -36.95  Caatinga
# 2019-01-01 16:38:24        1.0     -5.56     -39.58  Caatinga
# 2019-01-01 16:38:24        1.0     -5.33     -39.52  Caatinga
#
#
# Pantanal 2019
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2019-01-03 17:44:23        1.0    -15.74     -57.98  Pantanal
# 2019-01-07 18:09:42        1.0    -19.03     -57.12  Pantanal
# 2019-01-11 13:30:00        1.0    -19.00     -57.28  Pantanal
#
#
# Mata Atlantica 2019
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2019-01-01 21:49:42        1.0     -7.38     -35.16  Mata Atlantica
# 2019-01-02 16:20:54        1.0    -21.87     -45.47  Mata Atlantica
# 2019-01-02 16:20:54        1.0     -9.90     -36.14  Mata Atlantica
#
#
# Pampa 2019
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2019-03-28 17:18:00        1.0    -31.40     -53.88  Pampa
# 2019-03-28 17:18:00        1.0    -31.14     -52.61  Pampa
# 2019-03-28 17:18:00        1.0    -31.33     -54.06  Pampa
#
#
# Cerrado 2019
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2019-01-06 17:42:00        1.0    -20.38     -54.85  Cerrado
# 2019-01-08 17:06:00        1.0    -16.47     -52.25  Cerrado
# 2019-01-08 17:52:12        1.0    -15.98     -53.58  Cerrado
#
#
# Amazonia 2020
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2020-02-20 16:35:55        1.0      3.89     -60.23  Amazonia
# 2020-02-20 16:35:55        1.0      3.87     -60.23  Amazonia
# 2020-02-20 16:35:54        1.0      3.86     -60.21  Amazonia
#
#
# Caatinga 2020
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2020-02-19 16:04:41        1.0     -7.38     -36.06  Caatinga
# 2020-02-19 16:04:41        1.0     -7.40     -36.00  Caatinga
# 2020-02-19 16:04:41        1.0     -7.38     -36.00  Caatinga
#
#
# Pantanal 2020
#                      riscofogo  latitude  longitude     bioma
# datahora
# 2020-03-14 17:24:00        1.0    -18.64     -56.29  Pantanal
# 2020-03-14 17:24:00        1.0    -18.64     -56.29  Pantanal
# 2020-03-27 19:13:33        1.0    -17.82     -55.40  Pantanal
#
#
# Mata Atlantica 2020
#                      riscofogo  latitude  longitude           bioma
# datahora
# 2020-03-28 04:36:29        1.0    -21.36     -49.97  Mata Atlantica
# 2020-04-02 16:24:00        1.0    -22.99     -50.20  Mata Atlantica
# 2020-04-02 16:24:00        1.0    -22.99     -50.20  Mata Atlantica
#
#
# Pampa 2020
#                      riscofogo  latitude  longitude  bioma
# datahora
# 2020-04-15 17:18:00        1.0    -29.92     -53.28  Pampa
# 2020-04-15 17:18:00        1.0    -30.23     -53.03  Pampa
# 2020-04-15 17:18:00        1.0    -29.14     -56.12  Pampa
#
#
# Cerrado 2020
#                      riscofogo  latitude  longitude    bioma
# datahora
# 2020-03-28 04:36:29        1.0    -20.41     -55.66  Cerrado
# 2020-03-28 04:36:29        1.0    -20.40     -55.66  Cerrado
# 2020-04-11 17:00:00        1.0    -17.25     -52.95  Cerrado
